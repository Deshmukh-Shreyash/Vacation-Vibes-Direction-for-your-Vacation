# %%
import numpy as np
import pandas as pd

# %%
tourist = pd.read_csv("Final Tourist Places.csv")
tourist
# Out:
#      Palce_State Place_District Place_City                        Place_Name  \
# 0    Maharashtra      Ratnagiri  Ratnagiri                    Prachin Konkan
# 1    Maharashtra      Ratnagiri  Ratnagiri  Shree Mahalakshmi's House of Wax
# 2    Maharashtra      Ratnagiri  Ratnagiri                Jaigad Light House
# 3    Maharashtra      Ratnagiri  Ratnagiri          Shree Ganpatipule Mandir
# 4    Maharashtra      Ratnagiri  Ratnagiri                      Magic Garden
# ..           ...            ...        ...                               ...
# 724  Maharashtra           Pune   Lonavala              Indrayani view point
# 725  Maharashtra           Pune   Lonavala                        Adoshi Dam
# 726  Maharashtra           Pune   Lonavala                             Karla
# 727  Maharashtra           Pune   Lonavala                 RAJMACHI CAMPSITE
# 728  Maharashtra           Pune   Lonavala                Pawna lake camping
#
#      Place_Rating      Place_Category  \
# ...

# %%
tourist.isnull().sum()
# Out:
# Palce_State            0
# Place_District         0
# Place_City             0
# Place_Name             0
# Place_Rating           0
# Place_Category         0
# Place_Address          0
# Place_GPS_Code         0
# Place_Description    312
# Place_Map_Link         0
# Place_Photo            0
# Unnamed: 11          719
# dtype: int64

# %%
tourist = tourist.dropna(subset=['Place_Rating','Place_Description'])
tourist
# Out:
#      Palce_State Place_District Place_City                        Place_Name  \
# 0    Maharashtra      Ratnagiri  Ratnagiri                    Prachin Konkan
# 1    Maharashtra      Ratnagiri  Ratnagiri  Shree Mahalakshmi's House of Wax
# 2    Maharashtra      Ratnagiri  Ratnagiri                Jaigad Light House
# 3    Maharashtra      Ratnagiri  Ratnagiri          Shree Ganpatipule Mandir
# 4    Maharashtra      Ratnagiri  Ratnagiri                      Magic Garden
# ..           ...            ...        ...                               ...
# 717  Maharashtra           Pune   Lonavala                      Ulhas valley
# 718  Maharashtra           Pune   Lonavala            Shriwardhan Ballekilla
# 719  Maharashtra           Pune   Lonavala       Joshis Arundhati Activities
# 720  Maharashtra           Pune   Lonavala                    Magic Mountain
# 722  Maharashtra           Pune   Lonavala                     Tungarli Lake
#
#      Place_Rating      Place_Category  \
# ...

# %%
tourist2 = tourist[['Place_Name' ,'Place_City', 'Place_Category', 'Place_Description', 'Place_Rating']]
tourist2
# Out:
#                            Place_Name Place_City      Place_Category  \
# 0                      Prachin Konkan  Ratnagiri              Museum
# 1    Shree Mahalakshmi's House of Wax  Ratnagiri              Museum
# 2                  Jaigad Light House  Ratnagiri  Tourist attraction
# 3            Shree Ganpatipule Mandir  Ratnagiri              Temple
# 4                        Magic Garden  Ratnagiri                Park
# ..                                ...        ...                 ...
# 717                      Ulhas valley   Lonavala  Tourist attraction
# 718            Shriwardhan Ballekilla   Lonavala            Fortress
# 719       Joshis Arundhati Activities   Lonavala  Tourist attraction
# 720                    Magic Mountain   Lonavala                Park
# 722                     Tungarli Lake   Lonavala                Lake
#
#                                      Place_Description  Place_Rating
# 0                     Open-air regional history museum           4.3
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
tourist2['Place_Category'] = tourist2['Place_Category'].apply(lambda x:x.split())
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/1894049615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_Category'] = tourist2['Place_Category'].apply(lambda x:x.split())

# %%
tourist2
# Out:
#                            Place_Name Place_City         Place_Category  \
# 0                      Prachin Konkan  Ratnagiri               [Museum]
# 1    Shree Mahalakshmi's House of Wax  Ratnagiri               [Museum]
# 2                  Jaigad Light House  Ratnagiri  [Tourist, attraction]
# 3            Shree Ganpatipule Mandir  Ratnagiri               [Temple]
# 4                        Magic Garden  Ratnagiri                 [Park]
# ..                                ...        ...                    ...
# 717                      Ulhas valley   Lonavala  [Tourist, attraction]
# 718            Shriwardhan Ballekilla   Lonavala             [Fortress]
# 719       Joshis Arundhati Activities   Lonavala  [Tourist, attraction]
# 720                    Magic Mountain   Lonavala                 [Park]
# 722                     Tungarli Lake   Lonavala                 [Lake]
#
#                                      Place_Description  Place_Rating
# ...

# %%
tourist2['Place_Category'] = tourist2['Place_Category'].apply(collapse)
tourist2.head()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/2336079726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_Category'] = tourist2['Place_Category'].apply(collapse)
#                          Place_Name Place_City         Place_Category  \
# 0                    Prachin Konkan  Ratnagiri               [Museum]
# 1  Shree Mahalakshmi's House of Wax  Ratnagiri               [Museum]
# 2                Jaigad Light House  Ratnagiri  [Tourist, attraction]
# 3          Shree Ganpatipule Mandir  Ratnagiri               [Temple]
# 4                      Magic Garden  Ratnagiri                 [Park]
#
#                                    Place_Description  Place_Rating
# ...

# %%
tourist2['Place_Category'] = tourist2['Place_Category'].apply(lambda x: "".join(x))
tourist2.head()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/468325760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_Category'] = tourist2['Place_Category'].apply(lambda x: "".join(x))
#                          Place_Name Place_City     Place_Category  \
# 0                    Prachin Konkan  Ratnagiri             Museum
# 1  Shree Mahalakshmi's House of Wax  Ratnagiri             Museum
# 2                Jaigad Light House  Ratnagiri  Touristattraction
# 3          Shree Ganpatipule Mandir  Ratnagiri             Temple
# 4                      Magic Garden  Ratnagiri               Park
#
#                                    Place_Description  Place_Rating
# 0                   Open-air regional history museum           4.3
# ...

# %%
# tourist2['Place_City'] = tourist2['Place_City'].apply(collapse)

# %%
# tourist2['Place_City'] = tourist2['Place_City'].apply(lambda x: "".join(x))
# tourist2.head()

# %%
tourist2['Place_Description'] = tourist2['Place_Description'].apply(lambda x:x.split())
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/3849560830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_Description'] = tourist2['Place_Description'].apply(lambda x:x.split())

# %%
tourist2
# Out:
#                            Place_Name Place_City     Place_Category  \
# 0                      Prachin Konkan  Ratnagiri             Museum
# 1    Shree Mahalakshmi's House of Wax  Ratnagiri             Museum
# 2                  Jaigad Light House  Ratnagiri  Touristattraction
# 3            Shree Ganpatipule Mandir  Ratnagiri             Temple
# 4                        Magic Garden  Ratnagiri               Park
# ..                                ...        ...                ...
# 717                      Ulhas valley   Lonavala  Touristattraction
# 718            Shriwardhan Ballekilla   Lonavala           Fortress
# 719       Joshis Arundhati Activities   Lonavala  Touristattraction
# 720                    Magic Mountain   Lonavala               Park
# 722                     Tungarli Lake   Lonavala               Lake
#
#                                      Place_Description  Place_Rating
# 0                [Open-air, regional, history, museum]           4.3
# ...

# %%
# tourist2['Place_Category'] = tourist2['Place_Category'].apply(lambda x:x.split())

# %%
tourist2['Place_Category'] = tourist2.Place_Category.apply(lambda x: x[0:].split(','))
tourist2.head()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/3806262521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_Category'] = tourist2.Place_Category.apply(lambda x: x[0:].split(','))
#                          Place_Name Place_City       Place_Category  \
# 0                    Prachin Konkan  Ratnagiri             [Museum]
# 1  Shree Mahalakshmi's House of Wax  Ratnagiri             [Museum]
# 2                Jaigad Light House  Ratnagiri  [Touristattraction]
# 3          Shree Ganpatipule Mandir  Ratnagiri             [Temple]
# 4                      Magic Garden  Ratnagiri               [Park]
#
#                                    Place_Description  Place_Rating
# ...

# %%
tourist2['Place_City'] = tourist2.Place_City.apply(lambda x: x[0:].split(','))
tourist2.head()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/3695480806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['Place_City'] = tourist2.Place_City.apply(lambda x: x[0:].split(','))
#                          Place_Name   Place_City       Place_Category  \
# 0                    Prachin Konkan  [Ratnagiri]             [Museum]
# 1  Shree Mahalakshmi's House of Wax  [Ratnagiri]             [Museum]
# 2                Jaigad Light House  [Ratnagiri]  [Touristattraction]
# 3          Shree Ganpatipule Mandir  [Ratnagiri]             [Temple]
# 4                      Magic Garden  [Ratnagiri]               [Park]
#
#                                    Place_Description  Place_Rating
# ...

# %%
tourist2['tags'] = tourist2['Place_Category'] + tourist2['Place_Description'] + tourist2['Place_City']
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_3600/1289599187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tourist2['tags'] = tourist2['Place_Category'] + tourist2['Place_Description'] + tourist2['Place_City']

# %%
tourist2
# Out:
#                            Place_Name   Place_City       Place_Category  \
# 0                      Prachin Konkan  [Ratnagiri]             [Museum]
# 1    Shree Mahalakshmi's House of Wax  [Ratnagiri]             [Museum]
# 2                  Jaigad Light House  [Ratnagiri]  [Touristattraction]
# 3            Shree Ganpatipule Mandir  [Ratnagiri]             [Temple]
# 4                        Magic Garden  [Ratnagiri]               [Park]
# ..                                ...          ...                  ...
# 717                      Ulhas valley   [Lonavala]  [Touristattraction]
# 718            Shriwardhan Ballekilla   [Lonavala]           [Fortress]
# 719       Joshis Arundhati Activities   [Lonavala]  [Touristattraction]
# 720                    Magic Mountain   [Lonavala]               [Park]
# 722                     Tungarli Lake   [Lonavala]               [Lake]
#
#                                      Place_Description  Place_Rating  \
# ...

# %%
new = tourist2.drop(columns=['Place_City','Place_Category','Place_Description'])
new
# Out:
#                            Place_Name  Place_Rating  \
# 0                      Prachin Konkan           4.3
# 1    Shree Mahalakshmi's House of Wax           3.0
# 2                  Jaigad Light House           4.3
# 3            Shree Ganpatipule Mandir           4.7
# 4                        Magic Garden           4.1
# ..                                ...           ...
# 717                      Ulhas valley           4.5
# 718            Shriwardhan Ballekilla           4.6
# 719       Joshis Arundhati Activities           5.0
# 720                    Magic Mountain           4.3
# 722                     Tungarli Lake           4.4
#
#                                                   tags
# 0    [Museum, Open-air, regional, history, museum, ...
# 1                               [Museum, -, Ratnagiri]
# 2                    [Touristattraction, -, Ratnagiri]
# 3    [Temple, Temple,, believed, to, be, hundreds, ...
# 4                                 [Park, -, Ratnagiri]
# ...

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#                          Place_Name  Place_Rating  \
# 0                    Prachin Konkan           4.3
# 1  Shree Mahalakshmi's House of Wax           3.0
# 2                Jaigad Light House           4.3
# 3          Shree Ganpatipule Mandir           4.7
# 4                      Magic Garden           4.1
#
#                                                 tags
# 0  Museum Open-air regional history museum Ratnagiri
# 1                                 Museum - Ratnagiri
# 2                      Touristattraction - Ratnagiri
# 3  Temple Temple, believed to be hundreds of year...
# 4                                   Park - Ratnagiri

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (417, 538)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.70710678, 0.23570226, ..., 0.        , 0.        ,
#         0.        ],
#        [0.70710678, 1.        , 0.5       , ..., 0.        , 0.        ,
#         0.        ],
#        [0.23570226, 0.5       , 1.        , ..., 0.26726124, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.26726124, ..., 1.        , 0.15430335,
#         0.13363062],
#        [0.        , 0.        , 0.        , ..., 0.15430335, 1.        ,
#         0.4330127 ],
#        [0.        , 0.        , 0.        , ..., 0.13363062, 0.4330127 ,
#         1.        ]])

# %%
new[new['Place_Name'] == 'Prachin Konkan'].index[0]
# Out:
# 0

# %%
def recommend(place):
    index = new[new['Place_Name'] == place].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].Place_Name)

# %%
recommend('Shree Ganpatipule Mandir')
# Out:
# Ganapatipule Temple
# Devghali Beach, Kasheli
# Jai Vinayak Temple
# Ganpati Temple
# Shree Devi Bhagavati Temple
